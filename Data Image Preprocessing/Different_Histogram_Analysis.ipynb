# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import PIL
from PIL import Image
from matplotlib import pyplot as plt

im = Image.open('/content/drive/MyDrive/deeplabv3plus/Deeplabv3plus1/datasets/data/cloud/data/train/train/CLD00038_RGB_K3_NIA0038.png')  
w, h = im.size  
colors = im.getcolors(w*h)

def hexencode(rgb):
    r=rgb[0]
    g=rgb[1]
    b=rgb[2]
    return '#%02x%02x%02x' % (r,g,b)

for idx, c in enumerate(colors):
     plt.bar(idx, c[0], color=hexencode(c[1]),edgecolor=hexencode(c[1]))

plt.show()

# %%
from PIL import Image
im = Image.open('/content/drive/MyDrive/deeplabv3plus/Deeplabv3plus1/datasets/data/cloud/data/train/train/CLD00038_RGB_K3_NIA0038.png', 'r')
width, height = im.size
pixel_values = list(im.getdata())

# %%
im.mode
# Out:
# 'RGB'

# %%
import numpy
from PIL import Image


def get_image(image_path):
    """Get a numpy array of an image so that one can access values[x][y]."""
    image = Image.open(image_path, "r")
    width, height = image.size
    pixel_values = list(image.getdata())
    if image.mode == "RGB":
        channels = 3
    elif image.mode == "L":
        channels = 1
    else:
        print("Unknown mode: %s" % image.mode)
        return None
    pixel_values = numpy.array(pixel_values).reshape((width, height, channels))
    return pixel_values


image = get_image('/content/drive/MyDrive/deeplabv3plus/Deeplabv3plus1/datasets/data/cloud/data/train/train/CLD00038_RGB_K3_NIA0038.png')

print(image[0])
print(image.shape)
# Out:
# [[  0   0   0]
#  [  0   0   0]
#  [  0   0   0]
#  ...
#  [ 44  40  49]
#  [ 47  43  71]
#  [ 83  73 106]]
# (6015, 5591, 3)

# %%
import numpy as np
import skimage.color
import skimage.io
import matplotlib.pyplot as plt

# read original image, in full color
image = skimage.io.imread('/content/drive/MyDrive/deeplabv3plus/Deeplabv3plus1/datasets/data/cloud/data/train/train/CLD00038_RGB_K3_NIA0038.png')

# display the image
fig, ax = plt.subplots()
plt.imshow(image)
plt.show()

# %%
colors = ("red", "green", "blue")
channel_ids = (0, 1, 2)

# create the histogram plot, with three lines, one for
# each color
plt.figure()
plt.xlim([0, 256])
for channel_id, c in zip(channel_ids, colors):
    histogram, bin_edges = np.histogram(
        image[:, :, channel_id], bins=256, range=(0, 256)
    )
    plt.plot(bin_edges[0:-1], histogram, color=c)

plt.title("Color Histogram")
plt.xlabel("Color value")
plt.ylabel("Pixel count")

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
  
img = cv2.imread('/content/drive/MyDrive/data_grayscale_png/CLD00001_RGB_K3A_NIA0001.png')

# Calculate histogram without mask
hist1 = cv2.calcHist([img],[0],None,[256],[0,256])
hist2 = cv2.calcHist([img],[1],None,[256],[0,256])
hist3 = cv2.calcHist([img],[2],None,[256],[0,256])

plt.subplot(221), plt.imshow(img)
plt.subplot(222), plt.plot(hist1), plt.plot(hist2),plt.plot(hist3)
plt.xlim([0,256])

print("histg.shape:", hist1.shape)  #--③ 히스토그램의 shape (256,1)
print("histg.sum():", hist.sum(), "img.shape:",img.shape) #--④ 히스토그램 총 합계와 이미지의 크기

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
  
img = cv2.imread('/content/drive/MyDrive/data_grayscale_png/CLD00023_RGB_K3A_NIA0023.png')

# Calculate histogram without mask
histg = cv2.calcHist([img],[0],None,[256],[0,256])

plt.subplot(221), plt.imshow(img)
plt.subplot(222), plt.plot(histg)
plt.xlim([0,256])

print("histg.shape:", histg.shape)  #--③ 히스토그램의 shape (256,1)
print("histg.sum():", histg.sum(), "img.shape:",img.shape) #--④ 히스토그램 총 합계와 이미지의 크기
plt.title('CLD00023_RGB_K3A_NIA0023.png', fontsize=15)

plt.show()
# Out:
# histg.shape: (256, 1)
# histg.sum(): 36811800.0 img.shape: (6120, 6015, 3)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread('/content/drive/MyDrive/data_grayscale_png/CLD00001_RGB_K3A_NIA0001.png')

hist1 = cv2.calcHist([img],[0],None,[256],[0,256])

for x, y in enumerate(hist1):
    cv2.line(result, (int(x), image.shape[0]), (int(x), image.shape[0] - int(y)), 255)


dst = np.hstack([image[:, :, 0], result])

plt.plot(histr)
plt.show("dst", dst)

# %%
# importing required libraries of opencv
import cv2

# importing library for plotting
from matplotlib import pyplot as plt

# reads an input image
img = cv2.imread('/content/drive/MyDrive/data_grayscale_png/CLD00001_RGB_K3A_NIA0001.png',0)

# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])

# show the plotting graph of an image
plt.plot(histr)
plt.show()

6015*5000

# %%
import cv2
import os
from matplotlib import pyplot as plt

img2 = os.listdir('/content/drive/MyDrive/data_grayscale_png')

img = cv2.imread('/content/drive/MyDrive/data_grayscale_png/CLD00022_RGB_K3A_NIA0022.png',0)
img2 = cv2.imread('/content/drive/MyDrive/data_grayscale_png/CLD00004_RGB_K3A_NIA0004.png',0)
# alternative way to find histogram of an image
histg = cv2.calcHist([img],[0],None,[256],[0,256]) 
histg2 = cv2.calcHist([img2],[0],None,[256],[0,256])
plt.plot(histg)
plt.plot(histg2)

print("histg.shape:", histg.shape)  #--③ 히스토그램의 shape (256,1)
print("histg.sum():", histg.sum(), "img.shape:",img.shape) #--④ 히스토그램 총 합계와 이미지의 크기

plt.show()
# Out:
# histg.shape: (256, 1)
# histg.sum(): 36150148.0 img.shape: (6010, 6015)

# %%
import cv2

src = cv2.imread('/content/drive/MyDrive/data_grayscale_png/CLD00022_RGB_K3A_NIA0022.png', cv2.IMREAD_COLOR)
hsv = cv2.cvtColor(src, cv2.COLOR_BGR2HSV)
h, s, v = cv2.split(hsv)

cv2.imshow("h", h)
cv2.imshow("s", s)
cv2.imshow("v", v)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-29-a146d5051866> in <module>()
#       5 v = cv2.split(hsv)
#       6
# ----> 7 cv2.imshow("v", v)
#       8 cv2.waitKey()
#       9 cv2.destroyAllWindows()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
import cv2, numpy as np
from matplotlib import pyplot as plt

img1 = cv2.imread('/content/drive/MyDrive/deeplabv3plus/Deeplabv3plus1/datasets/data/cloud/label/train/train/CLD00001_RGB_K3A_NIA0001_label.png')
img2 = cv2.imread('/content/drive/MyDrive/deeplabv3plus/Deeplabv3plus1/datasets/data/cloud/label/train/train/CLD00003_RGB_K3A_NIA0003_label.png')
img3 = cv2.imread('/content/drive/MyDrive/deeplabv3plus/Deeplabv3plus1/datasets/data/cloud/label/train/train/CLD00005_RGB_K3A_NIA0005_label.png')
img4 = cv2.imread('/content/drive/MyDrive/deeplabv3plus/Deeplabv3plus1/datasets/data/cloud/label/train/train/CLD00012_RGB_K3A_NIA0012_label.png')


imgs = [img1, img2, img3, img4]
hists = []
for i, img in enumerate(imgs) :
    plt.subplot(1,len(imgs),i+1)
    plt.title('img%d'% (i+1))
    plt.axis('off') 
    plt.imshow(img[:,:,::-1])
    #---① 각 이미지를 HSV로 변환
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    #---② H,S 채널에 대한 히스토그램 계산
    hist = cv2.calcHist([hsv], [0,1], None, [180,256], [0,180,0, 256])
    #---③ 0~1로 정규화
    cv2.normalize(hist, hist, 0, 1, cv2.NORM_MINMAX)
    hists.append(hist)


query = hists[0]
methods = {'CORREL' :cv2.HISTCMP_CORREL, 'CHISQR':cv2.HISTCMP_CHISQR, 
           'INTERSECT':cv2.HISTCMP_INTERSECT,
           'BHATTACHARYYA':cv2.HISTCMP_BHATTACHARYYA}
for j, (name, flag) in enumerate(methods.items()):
    print('%-10s'%name, end='\t')
    for i, (hist, img) in enumerate(zip(hists, imgs)):
        #---④ 각 메서드에 따라 img1과 각 이미지의 히스토그램 비교
        ret = cv2.compareHist(query, hist, flag)
        if flag == cv2.HISTCMP_INTERSECT: #교차 분석인 경우 
            ret = ret/np.sum(query)        #비교대상으로 나누어 1로 정규화
        print("img%d:%7.2f"% (i+1 , ret), end='\t')
    print()
plt.show()
# Out:
# CORREL    	img1:   1.00	img2:   1.00	img3:   1.00	img4:   1.00
# CHISQR    	img1:   0.00	img2:   0.00	img3:   0.00	img4:   0.00
# INTERSECT 	img1:   1.00	img2:   1.00	img3:   1.00	img4:   1.00
# BHATTACHARYYA	img1:   0.00	img2:   0.00	img3:   0.00	img4:   0.00

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

#--① 그레이 스케일로 영상 읽기
img = cv2.imread('/content/drive/MyDrive/deeplabv3plus/Deeplabv3plus1/datasets/data/cloud/label/train/train/CLD00005_RGB_K3A_NIA0005_label.png', cv2.IMREAD_GRAYSCALE)

#--② 직접 연산한 정규화
img_f = img.astype(np.float32)
img_norm = ((img_f - img_f.min()) * (255) / (img_f.max() - img_f.min()))
img_norm = img_norm.astype(np.uint8)

#--③ OpenCV API를 이용한 정규화
img_norm2 = cv2.normalize(img, None, 0, 255, cv2.NORM_MINMAX)

#--④ 히스토그램 계산
hist = cv2.calcHist([img], [0], None, [256], [0, 256])
hist_norm = cv2.calcHist([img_norm], [0], None, [256], [0, 256])
hist_norm2 = cv2.calcHist([img_norm2], [0], None, [256], [0, 256])

plt.show()('Before', img)
plt.show()('Manual', img_norm)
plt.show()('cv2.normalize()', img_norm2)

hists = {'Before' : hist, 'Manual':hist_norm, 'cv2.normalize()':hist_norm2}
for i, (k, v) in enumerate(hists.items()):
    plt.subplot(1,3,i+1)
    plt.title(k)
    plt.plot(v)
plt.show()

# %%
import cv2
import matplotlib.pylab as plt

plt.style.use('classic')            # --①컬러 스타일을 1.x 스타일로 사용
img = plt.show ('/content/drive/MyDrive/deeplabv3plus/Deeplabv3plus1/datasets/data/cloud/label/train/train/CLD00005_RGB_K3A_NIA0005_label.png')

plt.subplot(131)
hist9 = cv2.calcHist([img], [0,1], None, [32,32], [0,256,0,256])
histg = cv2.calcHist([img],[0],None,[256],[0,256])  #--②
p = plt.imshow(hist)                                            #--③
plt.title('Blue and Green')                                     #--④
plt.colorbar(p)                                                 #--⑤


plt.subplot(132)
hist = cv2.calcHist([img], [1,2], None, [32,32], [0,256,0,256]) #--⑥
p = plt.imshow(hist)
plt.title('Green and Red')
plt.colorbar(p)

plt.subplot(133)
hist = cv2.calcHist([img], [0,2], None, [32,32], [0,256,0,256]) #--⑦
p = plt.imshow(hist)
plt.title('Blue and Red')
plt.colorbar(p)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-d5ef5fd66410> in <module>()
#       6
#       7 plt.subplot(131)
# ----> 8 hist = cv2.calcHist([img], [0,1], None, [32,32], [0,256,0,256]) #--②
#       9 p = plt.imshow(hist)                                            #--③
#      10 plt.title('Blue and Green')                                     #--④
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/histogram.cpp:158: error: (-215:Assertion failed) j < nimages in function 'histPrepareImages'
